# %% [markdown]
# # Evaluations

# %% [markdown]
# ## Get Recommendations

# %%
import json

with open('evaluation_data.json') as f:
    val = json.load(f)

# %%
val[0]
# Out:
# {'artist': 'Passion Pit',
#  'album': 'Manners',
#  'song': '09 Sleepyhead',
#  'start': 3767627,
#  'stop': 5090627,
#  'validation': True,
#  'embedding': [0.11278816312551498,
#   0.11143997311592102,
#   -0.11756818741559982,
#   -0.23810337483882904,
#   0.054074134677648544,
#   -0.027480294927954674,
#   0.2202390432357788,
#   0.07895691692829132,
#   0.24123559892177582,
#   0.11683941632509232,
#   -0.06588985025882721,
#   -0.2999226152896881,
#   -0.0035447711125016212,
#   -0.21891173720359802,
#   -0.17247919738292694,
#   0.10032028704881668,
#   -0.20257359743118286,
#   0.2879723012447357,
#   0.060127925127744675,
#   0.14642766118049622,
#   0.041968923062086105,
#   0.034772079437971115,
#   -0.08529561758041382,
#   -0.4657568335533142,
#   0.11055739969015121,
#   0.05489571765065193,
#   -0.052408117800951004,
#   -0.15117725729942322,
#   0.03145952522754669,
#   -0.044740334153175354,
#   -0.297035813331604,
#   -0.28945040702819824]}

# %%
import pandas as pd

df = pd.DataFrame(val)
df.head()
# Out:
#         artist    album                song    start     stop  validation  \
# 0  Passion Pit  Manners       09 Sleepyhead  3767627  5090627        True
# 1  Passion Pit  Manners       09 Sleepyhead  3855168  5178168        True
# 2  Passion Pit  Manners  08 Eyes As Candles  5459328  6782328       False
# 3  Passion Pit  Manners  08 Eyes As Candles  2532575  3855575       False
# 4  Passion Pit  Manners   02 Little Secrets  5270976  6593976        True
#
#                                            embedding
# 0  [0.11278816312551498, 0.11143997311592102, -0....
# 1  [0.11765195429325104, 0.09204290062189102, -0....
# 2  [0.16628490388393402, 0.060314495116472244, 0....
# 3  [0.29686233401298523, 0.016828976571559906, -0...
# 4  [0.2858065068721771, -0.1420089453458786, -0.0...

# %%
df['song'] = df.song.str.partition()[2]

# %%
df.head()
# Out:
#         artist    album             song    start     stop  validation  \
# 0  Passion Pit  Manners       Sleepyhead  3767627  5090627        True
# 1  Passion Pit  Manners       Sleepyhead  3855168  5178168        True
# 2  Passion Pit  Manners  Eyes As Candles  5459328  6782328       False
# 3  Passion Pit  Manners  Eyes As Candles  2532575  3855575       False
# 4  Passion Pit  Manners   Little Secrets  5270976  6593976        True
#
#                                            embedding
# 0  [0.11278816312551498, 0.11143997311592102, -0....
# 1  [0.11765195429325104, 0.09204290062189102, -0....
# 2  [0.16628490388393402, 0.060314495116472244, 0....
# 3  [0.29686233401298523, 0.016828976571559906, -0...
# 4  [0.2858065068721771, -0.1420089453458786, -0.0...

# %% [markdown]
# ## Get Similarity Data

# %%
import base64
import datetime as dt
import os
import requests as rq


SPOTIFY_API_URL = 'https://api.spotify.com/v1'
SPOTIFY_ID = os.environ.get('SPOTIFY_CLIENT_ID')
SPOTIFY_SECRET = os.environ.get('SPOTIFY_SECRET_ID')
SPOTIFY_CREDENTIALS = base64.b64encode((SPOTIFY_ID + ':' + SPOTIFY_SECRET).encode('utf-8')).decode('ascii')


def authenticate():
    return rq.post(
        'https://accounts.spotify.com/api/token',
        data={'grant_type': 'client_credentials'},
        headers={'Authorization': 'Basic ' + SPOTIFY_CREDENTIALS}
    ).json()


def get_session():
    auth_response = authenticate()
    access_token = auth_response['access_token']
    expiration_date = datetime.datetime.now() + datetime.timedelta(seconds = auth_response['expires_in'])
    def session(resource, *args, **kwargs):
        return rq.get(
            SPOTIFY_API_URL + resource,
            headers={'Authorization': 'Bearer ' + access_token},
            *args,
            **kwargs
        )
    return session, expiration_date


def search_tracks(session, artist, song):
    return session('/search', params={'q': f'{artist} {song}', 'type': 'track'}).json()

def parse_tracks(tracks):
    t = tracks['tracks']['items'][0]
    id = t['id']
    meta = {
        'track_name': t['name'],
        'album_name': t['album']['name'],
        'artist_names': ', '.join(a['name'] for a in t['artists'])}
    return id, meta


def get_audio_features(session, track_id):
    response = session(f'/audio-features/{track_id}')
    return response.json()


auth_response
# Out:
# {'access_token': 'BQCbDuf0QrWCoLfN2uom_fy4LUmkhf4TSTJmqalehpgt6VhoPmnMmht0yefWbNy8pmttzY7nx2Gea1Y2KUM',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
authenticate()
# Out:
# {'access_token': 'BQCBY40pHfqJDWWsDz4_VsR6fT9EhmNxcCAzrFAOWvY6yrtulLc400JK5pJlm3fjtwf-opvl7wEOY0K40ts',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
parse_tracks(r)
# Out:
# ('1Q5kgpp4pmyGqPwNBzkSrw',
#  {'track_name': 'Roadhouse Blues',
#   'album_name': 'Morrison Hotel',
#   'artist_names': 'The Doors'})

# %%
search_tracks(session, 'Death Cab For Cutie', 'Passenger Seat')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Death+Cab+For+Cutie+Passenger+Seat&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#        'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#        'id': '0YrtvWJMgSdVrk3SfNjTbx',
#        'name': 'Death Cab for Cutie',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jQW2mhMH3TxtAOol3Djuf'},
#      'href': 'https://api.spotify.com/v1/albums/4jQW2mhMH3TxtAOol3Djuf',
#      'id': '4jQW2mhMH3TxtAOol3Djuf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c306113cf2eea54867337da2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c306113cf2eea54867337da2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c306113cf2eea54867337da2',
#        'width': 64}],
#      'name': 'Transatlanticism (10th Anniversary Edition)',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4jQW2mhMH3TxtAOol3Djuf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#       'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#       'id': '0YrtvWJMgSdVrk3SfNjTbx',
#       'name': 'Death Cab for Cutie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBS50310286'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FF4q2qyOsFhRavZ0bdVXT'},
#     'href': 'https://api.spotify.com/v1/tracks/4FF4q2qyOsFhRavZ0bdVXT',
#     'id': '4FF4q2qyOsFhRavZ0bdVXT',
#     'is_local': False,
#     'name': 'Passenger Seat',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9cb973497289ad0bef16f01c30dfe453b6662c80?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:4FF4q2qyOsFhRavZ0bdVXT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#        'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#        'id': '0YrtvWJMgSdVrk3SfNjTbx',
#        'name': 'Death Cab for Cutie',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sfLsbSsDm780Llr9NWHQz'},
#      'href': 'https://api.spotify.com/v1/albums/2sfLsbSsDm780Llr9NWHQz',
#      'id': '2sfLsbSsDm780Llr9NWHQz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e9ee9a226a3ef6d6e26fbe67',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e9ee9a226a3ef6d6e26fbe67',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e9ee9a226a3ef6d6e26fbe67',
#        'width': 64}],
#      'name': 'Transatlanticism',
#      'release_date': '2003-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2sfLsbSsDm780Llr9NWHQz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#       'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#       'id': '0YrtvWJMgSdVrk3SfNjTbx',
#       'name': 'Death Cab for Cutie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBS50310286'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0eUm2fcFSfWH7m5ap3xvnE'},
#     'href': 'https://api.spotify.com/v1/tracks/0eUm2fcFSfWH7m5ap3xvnE',
#     'id': '0eUm2fcFSfWH7m5ap3xvnE',
#     'is_local': False,
#     'name': 'Passenger Seat',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9cb973497289ad0bef16f01c30dfe453b6662c80?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0eUm2fcFSfWH7m5ap3xvnE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#        'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#        'id': '0YrtvWJMgSdVrk3SfNjTbx',
#        'name': 'Death Cab for Cutie',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jQW2mhMH3TxtAOol3Djuf'},
#      'href': 'https://api.spotify.com/v1/albums/4jQW2mhMH3TxtAOol3Djuf',
#      'id': '4jQW2mhMH3TxtAOol3Djuf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c306113cf2eea54867337da2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c306113cf2eea54867337da2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c306113cf2eea54867337da2',
#        'width': 64}],
#      'name': 'Transatlanticism (10th Anniversary Edition)',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4jQW2mhMH3TxtAOol3Djuf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#       'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#       'id': '0YrtvWJMgSdVrk3SfNjTbx',
#       'name': 'Death Cab for Cutie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 199280,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBS51300054'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nSgmMy138jDPlJKE1Q3SE'},
#     'href': 'https://api.spotify.com/v1/tracks/5nSgmMy138jDPlJKE1Q3SE',
#     'id': '5nSgmMy138jDPlJKE1Q3SE',
#     'is_local': False,
#     'name': 'Passenger Seat (Demo)',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d739a0101bfe2f48ec6f02e7589cb0ee84c1131?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:5nSgmMy138jDPlJKE1Q3SE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#        'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#        'id': '0YrtvWJMgSdVrk3SfNjTbx',
#        'name': 'Death Cab for Cutie',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2XViusADo1OU8Yv3PqsVU6'},
#      'href': 'https://api.spotify.com/v1/albums/2XViusADo1OU8Yv3PqsVU6',
#      'id': '2XViusADo1OU8Yv3PqsVU6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273552a6fb7ea5928104bb999f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02552a6fb7ea5928104bb999f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851552a6fb7ea5928104bb999f5',
#        'width': 64}],
#      'name': 'Transatlanticism Demos',
#      'release_date': '2013-10-29',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2XViusADo1OU8Yv3PqsVU6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YrtvWJMgSdVrk3SfNjTbx'},
#       'href': 'https://api.spotify.com/v1/artists/0YrtvWJMgSdVrk3SfNjTbx',
#       'id': '0YrtvWJMgSdVrk3SfNjTbx',
#       'name': 'Death Cab for Cutie',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YrtvWJMgSdVrk3SfNjTbx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 199280,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBS51300054'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/15V5V2SHghBVRLBkX4NXKq'},
#     'href': 'https://api.spotify.com/v1/tracks/15V5V2SHghBVRLBkX4NXKq',
#     'id': '15V5V2SHghBVRLBkX4NXKq',
#     'is_local': False,
#     'name': 'Passenger Seat (Demo)',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d739a0101bfe2f48ec6f02e7589cb0ee84c1131?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:15V5V2SHghBVRLBkX4NXKq'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 8}}

# %%
artist, song
# Out:
# ('Death Cab For Cutie', 'Pessenger Seat')

# %%
import json
import time

from tqdm.notebook import tqdm

session, expiration_date = get_session()

artist_songs = df[['artist', 'song']].drop_duplicates()

for _, (artist, song) in tqdm(artist_songs.iterrows(), total=len(artist_songs)):
    output_dir = output_dir = os.path.join('audio-features', artist, song)
    output_dest = os.path.join(output_dir, 'audio_features.json')
    
    if os.path.exists(output_dest): continue

    # reauthenticate if necessary
    if dt.datetime.now() > expiration_date:
        session, expiration_date = get_session()

    try:
        # get track ID and meta data
        tracks = search_tracks(session, artist, song)
        track_id, track_meta = parse_tracks(tracks)
    except (KeyError, IndexError):
        continue

    # get the audio features
    audio_features = get_audio_features(session, track_id)
    
    # update the audio features and dump
    audio_features.update(track_meta)
    os.makedirs(output_dir, exist_ok=True)
    with open(output_dest, 'w') as f:
        json.dump(audio_features, f)

    time.sleep(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10904.0), HTML(value='')))

# %%
tracks
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Death+Cab+For+Cutie+%22Pessenger+Seat%22&type=track&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
r['tracks']['items'][0]['name']
# Out:
# 'Roadhouse Blues'

# %%
session = get_session()
track_id = get_track_id(session, 'The Doors', 'Roadhouse Blues')
get_audio_features(session, track_id)
# Out:
# {'danceability': 0.612,
#  'energy': 0.634,
#  'key': 9,
#  'loudness': -8.212,
#  'mode': 1,
#  'speechiness': 0.0319,
#  'acousticness': 0.337,
#  'instrumentalness': 4.6e-05,
#  'liveness': 0.147,
#  'valence': 0.904,
#  'tempo': 121.059,
#  'type': 'audio_features',
#  'id': '1Q5kgpp4pmyGqPwNBzkSrw',
#  'uri': 'spotify:track:1Q5kgpp4pmyGqPwNBzkSrw',
#  'track_href': 'https://api.spotify.com/v1/tracks/1Q5kgpp4pmyGqPwNBzkSrw',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Q5kgpp4pmyGqPwNBzkSrw',
#  'duration_ms': 243827,
#  'time_signature': 4}

# %%
session = get_session()
session('/audio-features/1Q5kgpp4pmyGqPwNBzkSrw')
# Out:
# <Response [200]>

# %%
access_token = auth_response['access_token']
access_token
# Out:
# 'BQCbDuf0QrWCoLfN2uom_fy4LUmkhf4TSTJmqalehpgt6VhoPmnMmht0yefWbNy8pmttzY7nx2Gea1Y2KUM'

# %%
query('/audio-features/1Q5kgpp4pmyGqPwNBzkSrw').json()
# Out:
# {'danceability': 0.612,
#  'energy': 0.634,
#  'key': 9,
#  'loudness': -8.212,
#  'mode': 1,
#  'speechiness': 0.0319,
#  'acousticness': 0.337,
#  'instrumentalness': 4.6e-05,
#  'liveness': 0.147,
#  'valence': 0.904,
#  'tempo': 121.059,
#  'type': 'audio_features',
#  'id': '1Q5kgpp4pmyGqPwNBzkSrw',
#  'uri': 'spotify:track:1Q5kgpp4pmyGqPwNBzkSrw',
#  'track_href': 'https://api.spotify.com/v1/tracks/1Q5kgpp4pmyGqPwNBzkSrw',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Q5kgpp4pmyGqPwNBzkSrw',
#  'duration_ms': 243827,
#  'time_signature': 4}

# %%
r = query('/search', params={'q': 'the doors "roadhouse blues"', 'type': 'track'}).json()
r
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=the+doors+%22roadhouse+blues%22&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6AFLOkpJjFF652jevcSOZX'},
#      'href': 'https://api.spotify.com/v1/albums/6AFLOkpJjFF652jevcSOZX',
#      'id': '6AFLOkpJjFF652jevcSOZX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ed63cae41138c76c4b25655',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ed63cae41138c76c4b25655',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ed63cae41138c76c4b25655',
#        'width': 64}],
#      'name': 'Morrison Hotel',
#      'release_date': '1970-02-09',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6AFLOkpJjFF652jevcSOZX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19900375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Q5kgpp4pmyGqPwNBzkSrw'},
#     'href': 'https://api.spotify.com/v1/tracks/1Q5kgpp4pmyGqPwNBzkSrw',
#     'id': '1Q5kgpp4pmyGqPwNBzkSrw',
#     'is_local': False,
#     'name': 'Roadhouse Blues',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ce4e9952e1519b9fe6c858b085fbe79077ec9dfb?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Q5kgpp4pmyGqPwNBzkSrw'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3OIjlStgBVQfGjkiftDAZp'},
#      'href': 'https://api.spotify.com/v1/albums/3OIjlStgBVQfGjkiftDAZp',
#      'id': '3OIjlStgBVQfGjkiftDAZp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d929a107229ef274c8b62e1e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d929a107229ef274c8b62e1e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d929a107229ef274c8b62e1e',
#        'width': 64}],
#      'name': 'The Future Starts Here: The Essential Doors Hits',
#      'release_date': '2008-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3OIjlStgBVQfGjkiftDAZp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 248146,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VHvZjaD1sdWA7vC4Dm2Au'},
#     'href': 'https://api.spotify.com/v1/tracks/4VHvZjaD1sdWA7vC4Dm2Au',
#     'id': '4VHvZjaD1sdWA7vC4Dm2Au',
#     'is_local': False,
#     'name': 'Roadhouse Blues - New Stereo Mix',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8fe8335e90fde29f90c0990538d05f2cc8793aed?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4VHvZjaD1sdWA7vC4Dm2Au'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7qj6lZyChZxDGAqzTArHHQ'},
#      'href': 'https://api.spotify.com/v1/albums/7qj6lZyChZxDGAqzTArHHQ',
#      'id': '7qj6lZyChZxDGAqzTArHHQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273661df6aa776da029b6802c0e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02661df6aa776da029b6802c0e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851661df6aa776da029b6802c0e',
#        'width': 64}],
#      'name': 'An American Prayer',
#      'release_date': '1978',
#      'release_date_precision': 'year',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:7qj6lZyChZxDGAqzTArHHQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 353026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10100411'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ILpNfKpRr7UWyJfk6UTHf'},
#     'href': 'https://api.spotify.com/v1/tracks/5ILpNfKpRr7UWyJfk6UTHf',
#     'id': '5ILpNfKpRr7UWyJfk6UTHf',
#     'is_local': False,
#     'name': 'Roadhouse Blues',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6fb1139b630a09dd47719e687a2ff38358c25175?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:5ILpNfKpRr7UWyJfk6UTHf'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YZiR5FINFOlZPGKSVplIY'},
#      'href': 'https://api.spotify.com/v1/albums/1YZiR5FINFOlZPGKSVplIY',
#      'id': '1YZiR5FINFOlZPGKSVplIY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf21ee0ee183384e7ca3f4f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf21ee0ee183384e7ca3f4f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf21ee0ee183384e7ca3f4f4',
#        'width': 64}],
#      'name': 'The Very Best of the Doors',
#      'release_date': '2007-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 39,
#      'type': 'album',
#      'uri': 'spotify:album:1YZiR5FINFOlZPGKSVplIY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 247466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/672KpkAb0iQ5rfJyicnZ3h'},
#     'href': 'https://api.spotify.com/v1/tracks/672KpkAb0iQ5rfJyicnZ3h',
#     'id': '672KpkAb0iQ5rfJyicnZ3h',
#     'is_local': False,
#     'name': 'Roadhouse Blues - New Stereo Mix',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bbaf3cad9b09f3e69932ce9715f2efdbf800c3c6?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 34,
#     'type': 'track',
#     'uri': 'spotify:track:672KpkAb0iQ5rfJyicnZ3h'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2VbXEqCO2C06ABWcZ8ymHI'},
#      'href': 'https://api.spotify.com/v1/albums/2VbXEqCO2C06ABWcZ8ymHI',
#      'id': '2VbXEqCO2C06ABWcZ8ymHI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737092d9007846a6c900c7e5f2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027092d9007846a6c900c7e5f2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517092d9007846a6c900c7e5f2',
#        'width': 64}],
#      'name': 'The Best of Rock and Roll Hall of Fame + Museum Live',
#      'release_date': '2011-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 51,
#      'type': 'album',
#      'uri': 'spotify:album:2VbXEqCO2C06ABWcZ8ymHI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0mXTJETA4XUa12MmmXxZJh'},
#       'href': 'https://api.spotify.com/v1/artists/0mXTJETA4XUa12MmmXxZJh',
#       'id': '0mXTJETA4XUa12MmmXxZJh',
#       'name': 'Eddie Vedder',
#       'type': 'artist',
#       'uri': 'spotify:artist:0mXTJETA4XUa12MmmXxZJh'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 349266,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUPV1100004'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4NQQclT8Kn1gn5Awhv6NyQ'},
#     'href': 'https://api.spotify.com/v1/tracks/4NQQclT8Kn1gn5Awhv6NyQ',
#     'id': '4NQQclT8Kn1gn5Awhv6NyQ',
#     'is_local': False,
#     'name': 'Roadhouse Blues (with Eddie Vedder)',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ffb589a4712f6ac56b7ac635f8cd5ee6828376b2?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 31,
#     'type': 'track',
#     'uri': 'spotify:track:4NQQclT8Kn1gn5Awhv6NyQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4YBBkcBOQi0kPcC89c3gof'},
#      'href': 'https://api.spotify.com/v1/albums/4YBBkcBOQi0kPcC89c3gof',
#      'id': '4YBBkcBOQi0kPcC89c3gof',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c5fee24761548cd9a6fd9b05',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c5fee24761548cd9a6fd9b05',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c5fee24761548cd9a6fd9b05',
#        'width': 64}],
#      'name': 'Live at the Isle of Wight Festival 1970',
#      'release_date': '2018-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4YBBkcBOQi0kPcC89c3gof'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 309800,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCBR1700288'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0yfr07KdaN1xz3c0iXrVdo'},
#     'href': 'https://api.spotify.com/v1/tracks/0yfr07KdaN1xz3c0iXrVdo',
#     'id': '0yfr07KdaN1xz3c0iXrVdo',
#     'is_local': False,
#     'name': 'Roadhouse Blues - Live At The Isle Of Wight Festival 1970',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0e3f12aa522ce5336880539ef52aba19afaa0ac8?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0yfr07KdaN1xz3c0iXrVdo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0MuuO7q58HbGU3qUjICucE'},
#      'href': 'https://api.spotify.com/v1/albums/0MuuO7q58HbGU3qUjICucE',
#      'id': '0MuuO7q58HbGU3qUjICucE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273288511eb7f87b1561f97fcfc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02288511eb7f87b1561f97fcfc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851288511eb7f87b1561f97fcfc',
#        'width': 64}],
#      'name': 'The Soft Parade (50th Anniversary Deluxe Edition)',
#      'release_date': '2019-11-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:0MuuO7q58HbGU3qUjICucE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 328802,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH11902730'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/38yGuAIwCFaleUMwRaRy2v'},
#     'href': 'https://api.spotify.com/v1/tracks/38yGuAIwCFaleUMwRaRy2v',
#     'id': '38yGuAIwCFaleUMwRaRy2v',
#     'is_local': False,
#     'name': "Roadhouse Blues (Screamin' Ray Daniels a.k.a. Ray Manzarek On Vocals)",
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/588dde843bf741b4167b87ff4a9e05d440ede4c5?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:38yGuAIwCFaleUMwRaRy2v'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1YZiR5FINFOlZPGKSVplIY'},
#      'href': 'https://api.spotify.com/v1/albums/1YZiR5FINFOlZPGKSVplIY',
#      'id': '1YZiR5FINFOlZPGKSVplIY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf21ee0ee183384e7ca3f4f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf21ee0ee183384e7ca3f4f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf21ee0ee183384e7ca3f4f4',
#        'width': 64}],
#      'name': 'The Very Best of the Doors',
#      'release_date': '2007-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 39,
#      'type': 'album',
#      'uri': 'spotify:album:1YZiR5FINFOlZPGKSVplIY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5eKLa1xyHLq8ERWmT1CRHj'},
#       'href': 'https://api.spotify.com/v1/artists/5eKLa1xyHLq8ERWmT1CRHj',
#       'id': '5eKLa1xyHLq8ERWmT1CRHj',
#       'name': 'The Crystal Method',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eKLa1xyHLq8ERWmT1CRHj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 297080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10504515'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0WKWG0jRr62dzriEHu53S9'},
#     'href': 'https://api.spotify.com/v1/tracks/0WKWG0jRr62dzriEHu53S9',
#     'id': '0WKWG0jRr62dzriEHu53S9',
#     'is_local': False,
#     'name': 'Roadhouse Blues - Crystal Method Remix',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a04b21d668a5dc1cb8486bd0e0d0189ee9b060b?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 39,
#     'type': 'track',
#     'uri': 'spotify:track:0WKWG0jRr62dzriEHu53S9'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0I4qWmnLr665zzPdIhRIB5'},
#      'href': 'https://api.spotify.com/v1/albums/0I4qWmnLr665zzPdIhRIB5',
#      'id': '0I4qWmnLr665zzPdIhRIB5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b22bbf5ada4099cfd4cc5a73',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b22bbf5ada4099cfd4cc5a73',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b22bbf5ada4099cfd4cc5a73',
#        'width': 64}],
#      'name': 'The Complete Studio Albums',
#      'release_date': '2012-10-22',
#      'release_date_precision': 'day',
#      'total_tracks': 79,
#      'type': 'album',
#      'uri': 'spotify:album:0I4qWmnLr665zzPdIhRIB5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 5,
#     'duration_ms': 244440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE11300749'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1AcCMOSqANTwaIznIxO3Ww'},
#     'href': 'https://api.spotify.com/v1/tracks/1AcCMOSqANTwaIznIxO3Ww',
#     'id': '1AcCMOSqANTwaIznIxO3Ww',
#     'is_local': False,
#     'name': 'Roadhouse Blues',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/838cd6fed30bd4f6dcce378e134eab9cf5140936?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1AcCMOSqANTwaIznIxO3Ww'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mKRzTeNQCK5bhFKK0LD1k'},
#      'href': 'https://api.spotify.com/v1/albums/4mKRzTeNQCK5bhFKK0LD1k',
#      'id': '4mKRzTeNQCK5bhFKK0LD1k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273746e05e2568a77f3832bc1dc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02746e05e2568a77f3832bc1dc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851746e05e2568a77f3832bc1dc',
#        'width': 64}],
#      'name': 'Live in New York',
#      'release_date': '2009',
#      'release_date_precision': 'year',
#      'total_tracks': 90,
#      'type': 'album',
#      'uri': 'spotify:album:4mKRzTeNQCK5bhFKK0LD1k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 261453,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10900878'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7031x2vSCqPznfz7eDgWCp'},
#     'href': 'https://api.spotify.com/v1/tracks/7031x2vSCqPznfz7eDgWCp',
#     'id': '7031x2vSCqPznfz7eDgWCp',
#     'is_local': False,
#     'name': 'Roadhouse Blues - Live at the Felt Forum, New York City, January 17, 1970, First Show',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b82f524bb3de1da6a494946744f97de98d615413?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7031x2vSCqPznfz7eDgWCp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27DiJLrgQmrf28DO4cdwY3'},
#      'href': 'https://api.spotify.com/v1/albums/27DiJLrgQmrf28DO4cdwY3',
#      'id': '27DiJLrgQmrf28DO4cdwY3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e928ce7e644f9a0fec804f33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e928ce7e644f9a0fec804f33',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e928ce7e644f9a0fec804f33',
#        'width': 64}],
#      'name': 'The Doors (Original Soundtrack Recording)',
#      'release_date': '1991-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:27DiJLrgQmrf28DO4cdwY3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 353026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10100411'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SEJLX94RMARFZaY3Mr3AQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1SEJLX94RMARFZaY3Mr3AQ',
#     'id': '1SEJLX94RMARFZaY3Mr3AQ',
#     'is_local': False,
#     'name': 'Roadhouse Blues',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4c09911fe2c1fbc42ca05ec9e31099fd48152dc?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1SEJLX94RMARFZaY3Mr3AQ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/437coS14MKFBIjXNj3bRAC'},
#      'href': 'https://api.spotify.com/v1/albums/437coS14MKFBIjXNj3bRAC',
#      'id': '437coS14MKFBIjXNj3bRAC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b03290cc000546090c5523b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b03290cc000546090c5523b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b03290cc000546090c5523b',
#        'width': 64}],
# ...
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 255360,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE11700121'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6D9KUZEZeVOY7DiKYZL1cU'},
#     'href': 'https://api.spotify.com/v1/tracks/6D9KUZEZeVOY7DiKYZL1cU',
#     'id': '6D9KUZEZeVOY7DiKYZL1cU',
#     'is_local': False,
#     'name': 'Roadhouse Blues - Live; 2017 Remaster [Remastered]',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/10ecf192b8f3d95727b9ef911fb35ee6b422d118?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6D9KUZEZeVOY7DiKYZL1cU'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wsbOwqXuuYw8c32ZGvGj5'},
#      'href': 'https://api.spotify.com/v1/albums/4wsbOwqXuuYw8c32ZGvGj5',
#      'id': '4wsbOwqXuuYw8c32ZGvGj5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273010fcba4390d24907099507a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02010fcba4390d24907099507a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851010fcba4390d24907099507a',
#        'width': 64}],
#      'name': 'Behind Closed Doors - The Rarities',
#      'release_date': '2013-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 58,
#      'type': 'album',
#      'uri': 'spotify:album:4wsbOwqXuuYw8c32ZGvGj5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 59160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608662'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RtaZTGKiDup5WVx617UpJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5RtaZTGKiDup5WVx617UpJ',
#     'id': '5RtaZTGKiDup5WVx617UpJ',
#     'is_local': False,
#     'name': 'Roadhouse Talking Blues',
#     'popularity': 15,
#     'preview_url': 'https://p.scdn.co/mp3-preview/01e7b0e2e34082629100316ea57a9cb3e6612ca4?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:5RtaZTGKiDup5WVx617UpJ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#        'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#        'id': '22WZ7M8sxp5THdruNY3gXt',
#        'name': 'The Doors',
#        'type': 'artist',
#        'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wsbOwqXuuYw8c32ZGvGj5'},
#      'href': 'https://api.spotify.com/v1/albums/4wsbOwqXuuYw8c32ZGvGj5',
#      'id': '4wsbOwqXuuYw8c32ZGvGj5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273010fcba4390d24907099507a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02010fcba4390d24907099507a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851010fcba4390d24907099507a',
#        'width': 64}],
#      'name': 'Behind Closed Doors - The Rarities',
#      'release_date': '2013-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 58,
#      'type': 'album',
#      'uri': 'spotify:album:4wsbOwqXuuYw8c32ZGvGj5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5eKLa1xyHLq8ERWmT1CRHj'},
#       'href': 'https://api.spotify.com/v1/artists/5eKLa1xyHLq8ERWmT1CRHj',
#       'id': '5eKLa1xyHLq8ERWmT1CRHj',
#       'name': 'The Crystal Method',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eKLa1xyHLq8ERWmT1CRHj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 297080,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10504515'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/75a2gNNuWhZXEU1n4g0eC1'},
#     'href': 'https://api.spotify.com/v1/tracks/75a2gNNuWhZXEU1n4g0eC1',
#     'id': '75a2gNNuWhZXEU1n4g0eC1',
#     'is_local': False,
#     'name': 'Roadhouse Blues - Crystal Method Remix',
#     'popularity': 14,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a04b21d668a5dc1cb8486bd0e0d0189ee9b060b?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 48,
#     'type': 'track',
#     'uri': 'spotify:track:75a2gNNuWhZXEU1n4g0eC1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1REs2cMpUq0knyOCAkzOZq'},
#      'href': 'https://api.spotify.com/v1/albums/1REs2cMpUq0knyOCAkzOZq',
#      'id': '1REs2cMpUq0knyOCAkzOZq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381b40155c89bd62456141571',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281b40155c89bd62456141571',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181b40155c89bd62456141571',
#        'width': 64}],
#      'name': 'Light My Fire - A Classic Rock Salute to the Doors',
#      'release_date': '2014-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:1REs2cMpUq0knyOCAkzOZq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ks4E3VJXDIRABtxz2IiBE'},
#       'href': 'https://api.spotify.com/v1/artists/0ks4E3VJXDIRABtxz2IiBE',
#       'id': '0ks4E3VJXDIRABtxz2IiBE',
#       'name': 'Leslie West',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ks4E3VJXDIRABtxz2IiBE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/304senzcXGpWqcpssNpmXJ'},
#       'href': 'https://api.spotify.com/v1/artists/304senzcXGpWqcpssNpmXJ',
#       'id': '304senzcXGpWqcpssNpmXJ',
#       'name': 'Brian Auger',
#       'type': 'artist',
#       'uri': 'spotify:artist:304senzcXGpWqcpssNpmXJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zWkGcXh8YmA2CFDGUosWX'},
#       'href': 'https://api.spotify.com/v1/artists/0zWkGcXh8YmA2CFDGUosWX',
#       'id': '0zWkGcXh8YmA2CFDGUosWX',
#       'name': 'Rod Piazza',
#       'type': 'artist',
#       'uri': 'spotify:artist:0zWkGcXh8YmA2CFDGUosWX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 247455,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMFMF1472895'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4M52M3PrWE6o6LzJozatPU'},
#     'href': 'https://api.spotify.com/v1/tracks/4M52M3PrWE6o6LzJozatPU',
#     'id': '4M52M3PrWE6o6LzJozatPU',
#     'is_local': False,
#     'name': 'Roadhouse Blues',
#     'popularity': 14,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f1f2e798fc86f6624579ccb8eb0a8ca58c20aa70?cid=1d140b1b6233442eb60c82c9f5fb8e68',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4M52M3PrWE6o6LzJozatPU'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=the+doors+%22roadhouse+blues%22&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 128}}

# %%
r['tracks']['items'][0]['album']['name'], r['tracks']['items'][0]['artists']
# Out:
# ('Morrison Hotel',
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#    'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#    'id': '22WZ7M8sxp5THdruNY3gXt',
#    'name': 'The Doors',
#    'type': 'artist',
#    'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}])

# %%
base64.b64encode((SPOTIFY_ID + ':' + SPOTIFY_SECRET).encode('utf-8')).decode('ascii')
# Out:
# 'MWQxNDBiMWI2MjMzNDQyZWI2MGM4MmM5ZjVmYjhlNjg6YmVlNDM5ZTg0MGNiNGZjZDgwNWRmNTdhYjZiYWY2NTQ='

# %%
access_token = auth_response.json()
# Out:
# {'access_token': 'BQB0l9QSWxUH6O8gDuli2iTlr9dh1LepS9hfAfoJO1_dPlwfsgKaoPpEmaaQHHdxJs2yipuzND84jiv2XZY',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %%
# import requests as rq

# similar_tracks = {}

# LASTFM_API_KEY = '18bc22feba5e7af41172c5b005d3a113'
# LASTFM_API_URL = 'http://ws.audioscrobbler.com/2.0/'
# LIMIT = 30


# def fetch_similar_tracks(artist, song):
#     try:
#         response = rq.get(LASTFM_API_URL, params={
#             'method': 'track.getsimilar',
#             'artist': artist,
#             'track': song,
#             'api_key': LASTFM_API_KEY,
#             'limit': 30,
#             'format': 'json'
#         }).json()
#         matches = extract_similarity_data(response)
#     except Exception as err:
#         return str(err)
#     return matches
    

# def extract_similarity_data(response):
#     tracks = response['similartracks']['track']
#     return [
#         {'song': t['name'], 'artist': t['artist']['name'], 'match': t['match']}
#         for t in tracks]
    

# response = fetch_similar_tracks('Grateful Dead', 'Fire On The Mountain')

# response
# Out:
# [{'song': "Franklin's Tower", 'artist': 'Grateful Dead', 'match': 1.0},
#  {'song': 'Estimated Prophet', 'artist': 'Grateful Dead', 'match': 0.988805},
#  {'song': 'Free', 'artist': 'Phish', 'match': 0.190383},
#  {'song': 'My Sisters And Brothers',
#   'artist': 'Jerry Garcia Band',
#   'match': 0.169381},
#  {'song': 'Stash', 'artist': 'Phish', 'match': 0.167339},
#  {'song': 'Greatest Story Ever Told', 'artist': 'Bob Weir', 'match': 0.147924},
#  {'song': 'Simple Twist of Fate',
#   'artist': 'Jerry Garcia Band',
#   'match': 0.147743},
#  {'song': 'Deal', 'artist': 'Jerry Garcia', 'match': 0.144996},
#  {'song': 'The Weight', 'artist': 'The Band', 'match': 0.136307},
#  {'song': 'Sugaree', 'artist': 'Jerry Garcia', 'match': 0.120767},
#  {'song': 'Blue Sky', 'artist': 'The Allman Brothers Band', 'match': 0.107484},
#  {'song': 'Dixie Chicken', 'artist': 'Little Feat', 'match': 0.0934525},
#  {'song': 'Jessica', 'artist': 'The Allman Brothers Band', 'match': 0.0923399},
#  {'song': 'Up On Cripple Creek', 'artist': 'The Band', 'match': 0.0914027},
#  {'song': 'Moondance', 'artist': 'Van Morrison', 'match': 0.0881836},
#  {'song': 'Sunshine of Your Love', 'artist': 'Cream', 'match': 0.0872103},
#  {'song': 'No Quarter', 'artist': 'Led Zeppelin', 'match': 0.0814691},
#  {'song': 'Riders on the Storm', 'artist': 'The Doors', 'match': 0.0793963},
#  {'song': 'Sweet Jane',
#   'artist': 'The Velvet Underground',
#   'match': 0.0788754},
#  {'song': "Jackie Wilson Said (I'm In Heaven When You Smile)",
#   'artist': 'Van Morrison',
#   'match': 0.0780221},
#  {'song': 'White Room', 'artist': 'Cream', 'match': 0.0766445},
#  {'song': "For What It's Worth",
#   'artist': 'Buffalo Springfield',
#   'match': 0.0756945},
#  {'song': 'Hyacinth House', 'artist': 'The Doors', 'match': 0.0746606},
#  {'song': 'Kashmir', 'artist': 'Led Zeppelin', 'match': 0.0736295},
#  {'song': "She's A Rainbow",
#   'artist': 'The Rolling Stones',
#   'match': 0.0731422},
#  {'song': 'Dear Mr. Fantasy', 'artist': 'Traffic', 'match': 0.0723652},
#  {'song': 'Embryonic Journey',
#   'artist': 'Jefferson Airplane',
#   'match': 0.0717197},
#  {'song': 'Magic Carpet Ride', 'artist': 'Steppenwolf', 'match': 0.0714166},
#  {'song': 'On Your Way Down', 'artist': 'Little Feat', 'match': 0.0705194},
#  {'song': 'You All Look Alike (Live)',
#   'artist': 'The Byrds',
#   'match': 0.0701349}]

# %%
# import time

# from tqdm.notebook import tqdm

# similar_songs = {}

# items = df[['artist', 'song']].drop_duplicates()

# for _, r in tqdm(items.iterrows(), total=len(items)):
#     similar_songs[(r.artist, r.song)] = fetch_similar_tracks(r.artist, r.song)
#     time.sleep(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10904.0), HTML(value='')))

# %%
# ! wget http://millionsongdataset.com/sites/default/files/lastfm/lastfm_train.zip
# ! unzip -q lastfm_train.zip

# %%
# ! wget http://millionsongdataset.com/sites/default/files/lastfm/lastfm_test.zip
# ! unzip -q lasstfm_test.zip
