# %%
import glob
import pickle

import scipy.io
import scipy.signal
import librosa
import numpy as np

# %%
files = glob.glob('data/raw/*wav')

# %%
files
# Out:
# ['data/raw/10 Cheye.wav',
#  'data/raw/04 Resol.wav',
#  'data/raw/06 Jammi.wav',
#  'data/raw/03 Death.wav',
#  'data/raw/08 Magnu.wav',
#  'data/raw/06 Stars.wav',
#  'data/raw/12 Snake.wav',
#  "data/raw/21 Let's.wav",
#  'data/raw/10 My De.wav',
#  'data/raw/15 Rocki.wav',
#  'data/raw/06 I Use.wav',
#  "data/raw/25 Don't.wav",
#  'data/raw/04 I Was.wav',
#  'data/raw/04 Learn.wav',
#  'data/raw/11 Lucky.wav',
#  'data/raw/12 Treas.wav',
#  'data/raw/04 U Got.wav',
#  'data/raw/22 Caref.wav',
#  'data/raw/11 Macau.wav',
#  'data/raw/02 Anody.wav',
#  'data/raw/02 Astro.wav',
#  'data/raw/17 Your .wav',
#  'data/raw/Intro - .wav',
#  'data/raw/08 Allig.wav',
#  'data/raw/02 Win.wav',
#  'data/raw/06 Rap G.wav',
#  'data/raw/05 Foxey.wav',
#  'data/raw/07 Bad O.wav',
#  'data/raw/07 Ripco.wav',
#  'data/raw/02 Circu.wav',
#  'data/raw/05 Firew.wav',
#  'data/raw/12 Dodo .wav',
#  'data/raw/07 The N.wav',
#  'data/raw/09 UR.wav',
#  'data/raw/10 I Wil.wav',
#  'data/raw/05 Highw.wav',
#  'data/raw/13 Play .wav',
#  "data/raw/08 Goin'.wav",
#  'data/raw/10 In Be.wav',
#  'data/raw/09 Jigsa.wav',
#  'data/raw/08 Bukow.wav',
#  'data/raw/tightrop.wav',
#  'data/raw/07 I Sta.wav',
#  'data/raw/13 Scatt.wav',
#  'data/raw/03 Live .wav',
#  'data/raw/01 Intro.wav',
#  'data/raw/07 Fathe.wav',
#  'data/raw/06 Honey.wav',
#  'data/raw/08 Set A.wav',
#  'data/raw/06 Runaw.wav',
#  'data/raw/07 Fitte.wav',
#  'data/raw/11 Life .wav',
#  'data/raw/09 Crazy.wav',
#  'data/raw/06 - Spi.wav',
#  'data/raw/02 Got S.wav',
#  'data/raw/18 Candi.wav',
#  'data/raw/15 Make .wav',
#  'data/raw/05 Shado.wav',
#  'data/raw/10 Bl(0).wav',
#  'data/raw/04 Voodo.wav',
#  'data/raw/03 I Got.wav',
#  'data/raw/05 - Kin.wav',
#  'data/raw/12 Spani.wav',
#  'data/raw/16 Deja .wav',
#  'data/raw/13 Circl.wav',
#  'data/raw/12 Paper.wav',
#  'data/raw/09 Sorro.wav',
#  'data/raw/10 Suffr.wav',
#  'data/raw/11 Voodo.wav',
#  'data/raw/Van Hale.wav',
#  'data/raw/Wang Chu.wav',
#  'data/raw/01 Godzi.wav',
#  'data/raw/04 One S.wav',
#  'data/raw/05 The M.wav',
#  'data/raw/03 Subte.wav',
#  'data/raw/04 - Som.wav',
#  'data/raw/10 The O.wav',
#  'data/raw/21 Camar.wav',
#  'data/raw/06 Youre.wav',
#  'data/raw/04 Hear .wav',
#  'data/raw/04 Are Y.wav',
#  'data/raw/09 Highw.wav',
#  'data/raw/11 Estra.wav',
#  'data/raw/14 One T.wav',
#  'data/raw/03 Fasci.wav',
#  "data/raw/09 I'm S.wav",
#  'data/raw/04 Searc.wav',
#  'data/raw/14 Flash.wav',
#  'data/raw/11 Melti.wav',
#  'data/raw/04 Fake .wav',
#  'data/raw/10 High .wav',
#  'data/raw/11 Not t.wav',
#  'data/raw/10 Gone .wav',
#  'data/raw/07 Shelt.wav',
#  'data/raw/08 You G.wav',
#  'data/raw/06 My Ch.wav',
#  'data/raw/04 Fire.wav',
#  'data/raw/15 - Air.wav',
#  'data/raw/17 Dolly.wav',
#  'data/raw/07 Track.wav',
#  'data/raw/16 The G.wav',
#  'data/raw/11- Hope.wav',
#  'data/raw/06 Lady .wav',
#  'data/raw/02 Sonne.wav',
#  'data/raw/03 Quart.wav',
#  'data/raw/09 Climb.wav',
#  'data/raw/02 You O.wav',
#  'data/raw/06 The S.wav',
#  'data/raw/14 Chloe.wav',
#  'data/raw/09 Summe.wav',
#  'data/raw/03 How Y.wav',
#  'data/raw/01 Shine.wav',
#  'data/raw/07 Can Y.wav',
#  'data/raw/05 On Th.wav',
#  'data/raw/03 Hey J.wav',
#  'data/raw/05 Bones.wav',
#  'data/raw/06 Death.wav',
#  'data/raw/07 Foxy .wav',
#  'data/raw/06 Alive.wav',
#  'data/raw/10 Rock .wav',
#  'data/raw/08 Devil.wav',
#  'data/raw/01 Plane.wav',
#  'data/raw/07 Dont .wav',
#  'data/raw/02 Damn .wav',
#  'data/raw/07 Invok.wav',
#  'data/raw/10 Nebul.wav',
#  'data/raw/12 Besid.wav',
#  'data/raw/22 Shut .wav',
#  'data/raw/03 Roost.wav',
#  'data/raw/09 Getti.wav',
#  'data/raw/14 Home .wav',
#  'data/raw/05 Glass.wav',
#  'data/raw/05 Soul .wav',
#  'data/raw/02 The P.wav',
#  'data/raw/06 This .wav',
#  'data/raw/15 Cloud.wav',
#  'data/raw/10 Storm.wav',
#  'data/raw/08 You A.wav',
#  'data/raw/04 Sysyp.wav',
#  'data/raw/14 Arise.wav',
#  'data/raw/09 Peopl.wav',
#  'data/raw/10 The V.wav',
#  'data/raw/13 R.A.K.wav',
#  'data/raw/05 Catch.wav',
#  'data/raw/01 Pleas.wav',
#  'data/raw/07 - Hop.wav',
#  'data/raw/10 Tiny .wav',
#  'data/raw/01 Be Ca.wav',
#  "data/raw/I don't .wav",
#  'data/raw/01 All A.wav',
#  'data/raw/10 On Me.wav',
#  'data/raw/09 Some .wav',
#  'data/raw/13 Stone.wav',
#  'data/raw/12 Sweep.wav',
#  'data/raw/04 - Mag.wav',
#  'data/raw/04 Islan.wav',
#  'data/raw/09 Carry.wav',
#  'data/raw/02 Them .wav',
#  'data/raw/13 Rebel.wav',
#  'data/raw/10 So Fi.wav',
#  'data/raw/04 Magic.wav',
#  'data/raw/11 In Pi.wav',
#  'data/raw/04 Deuce.wav',
#  'data/raw/13 Red H.wav',
#  'data/raw/08 - No .wav',
#  'data/raw/01 Beaut.wav',
#  'data/raw/07 - A T.wav',
#  'data/raw/17 Track.wav',
#  'data/raw/15 Union.wav',
#  'data/raw/14 Track.wav',
#  'data/raw/02 Burni.wav',
#  'data/raw/04 Papas.wav',
#  'data/raw/19 Rebel.wav',
#  'data/raw/03 Witho.wav',
#  'data/raw/15 Gypsy.wav',
#  'data/raw/08 Rever.wav',
#  'data/raw/01 Redef.wav',
#  'data/raw/10 Like .wav',
#  'data/raw/06 Oh, T.wav',
#  'data/raw/01 Mount.wav',
#  'data/raw/03 F.C.P.wav',
#  'data/raw/08 Termi.wav',
#  'data/raw/10 U Wan.wav',
#  'data/raw/02 Love .wav',
#  'data/raw/16 Voodo.wav',
#  'data/raw/09 Freed.wav',
#  'data/raw/03 Leave.wav',
#  'data/raw/20 Namas.wav',
#  'data/raw/03 The T.wav',
#  'data/raw/07 Dum D.wav',
#  'data/raw/10 I Was.wav',
#  'data/raw/07 In Th.wav',
#  'data/raw/09 Speed.wav',
#  'data/raw/06 Up on.wav',
#  'data/raw/07 Rainc.wav',
#  'data/raw/10 Bonus.wav',
#  'data/raw/04 Why I.wav',
#  'data/raw/11 Satin.wav',
#  'data/raw/18 - Mar.wav',
#  "data/raw/13 Goin'.wav",
#  'data/raw/Starship.wav',
#  'data/raw/11 Deep .wav',
#  'data/raw/10 Night.wav',
#  'data/raw/10 Forgo.wav',
#  'data/raw/16 We Wi.wav',
#  'data/raw/03 Worki.wav',
#  'data/raw/09 Love .wav',
#  'data/raw/13 Track.wav',
#  'data/raw/10 Highe.wav',
#  'data/raw/01 Colla.wav',
#  'data/raw/13 Numb.wav',
#  'data/raw/11 The E.wav',
#  'data/raw/05 Grant.wav',
#  'data/raw/03 8 Mil.wav',
#  'data/raw/14 Slow .wav',
#  'data/raw/05 Heart.wav',
#  'data/raw/12 Sessi.wav',
#  'data/raw/16 Tracy.wav',
#  'data/raw/01 Young.wav',
#  'data/raw/04 The L.wav',
#  'data/raw/12 Latin.wav',
#  'data/raw/06 (Nice.wav',
#  'data/raw/11 Celes.wav',
#  'data/raw/08 Weepi.wav',
#  'data/raw/10 Nosfe.wav',
#  'data/raw/12 Make .wav',
#  'data/raw/01 Beyon.wav',
#  'data/raw/11 Blame.wav',
#  'data/raw/12 You H.wav',
#  'data/raw/03 The F.wav',
#  'data/raw/13 Plast.wav',
#  'data/raw/08 Seatt.wav',
#  'data/raw/06 Junkh.wav',
#  'data/raw/01 Cygnu.wav',
#  'data/raw/09 Synco.wav',
#  'data/raw/04 Gangs.wav',
#  'data/raw/14 I Wis.wav',
#  'data/raw/07 8 Mil.wav',
#  'data/raw/12 Myxom.wav',
#  'data/raw/04 Navy .wav',
#  'data/raw/02 Baba.wav',
#  'data/raw/05 Mind .wav',
#  'data/raw/04 Angry.wav',
#  'data/raw/The Yard.wav',
#  'data/raw/03 The R.wav',
#  'data/raw/Valium.wav',
#  'data/raw/16 Maste.wav',
#  'data/raw/05 Someb.wav',
#  'data/raw/13 Who W.wav',
#  'data/raw/08 In Th.wav',
#  'data/raw/06 Remer.wav',
#  'data/raw/01 Wake.wav',
#  'data/raw/15 Dead .wav',
#  'data/raw/04 Sole .wav',
#  'data/raw/10 Innoc.wav',
#  'data/raw/12 1984D.wav',
#  'data/raw/01 Shake.wav',
#  'data/raw/09 Shimm.wav',
#  'data/raw/01 Track.wav',
#  'data/raw/09 Call .wav',
#  'data/raw/22 Muffi.wav',
#  'data/raw/03 Fucki.wav',
#  'data/raw/Armistic.wav',
#  'data/raw/04 Tira .wav',
#  'data/raw/08 Red H.wav',
#  'data/raw/12 Pushi.wav',
#  'data/raw/04 Hand .wav',
#  'data/raw/10 Black.wav',
#  'data/raw/12 The L.wav',
#  'data/raw/05 My Hu.wav',
#  'data/raw/11 A Pun.wav',
#  'data/raw/10 Out o.wav',
#  'data/raw/10 One L.wav',
#  'data/raw/09 Runaw.wav',
#  'data/raw/07 Come .wav',
#  'data/raw/07 Long .wav',
#  'data/raw/15 Joini.wav',
#  'data/raw/05 Sweet.wav',
#  'data/raw/03 Nude.wav',
#  'data/raw/12 Inter.wav',
#  'data/raw/03 Veter.wav',
#  'data/raw/08 Head .wav',
#  'data/raw/05 Mouth.wav',
#  'data/raw/19 Star .wav',
#  'data/raw/05 Keep .wav',
#  'data/raw/07 Faint.wav',
#  'data/raw/05 Littl.wav',
#  'data/raw/10 Porce.wav',
#  'data/raw/05 Get I.wav',
#  'data/raw/13 Right.wav',
#  'data/raw/16 Heart.wav',
#  'data/raw/02 1985.wav',
#  'data/raw/06 No Ti.wav',
#  'data/raw/14 Izabe.wav',
#  'data/raw/02 Actio.wav',
#  'data/raw/14 House.wav',
#  'data/raw/07 Signe.wav',
#  'data/raw/06 The M.wav',
#  'data/raw/13 Shove.wav',
#  'data/raw/01 All T.wav',
#  'data/raw/08 Ps(0).wav',
#  'data/raw/15 One C.wav',
#  'data/raw/04 Point.wav',
#  'data/raw/08 Basic.wav',
#  'data/raw/02 Have .wav',
#  'data/raw/01 2112.wav',
#  'data/raw/09 Faith.wav',
#  'data/raw/11 Track.wav',
#  'data/raw/03 Sweet.wav',
#  'data/raw/01 Purpl.wav',
#  'data/raw/05 The P.wav',
#  'data/raw/10 Frien.wav',
#  'data/raw/08 Grind.wav',
#  'data/raw/01 Horn .wav',
#  'data/raw/15 Up Up.wav',
#  'data/raw/08 Hang .wav',
#  'data/raw/01 Tom S.wav',
#  'data/raw/02 Uptig.wav',
#  'data/raw/02 - It .wav',
#  'data/raw/03 Track.wav',
#  'data/raw/06 Sinfu.wav',
#  'data/raw/11 Cure .wav',
#  'data/raw/11 The W.wav',
#  "data/raw/13 Don't.wav",
#  'data/raw/05 Crawl.wav',
#  'data/raw/01 Lose .wav',
#  'data/raw/01 Cut D.wav',
#  'data/raw/06 Long .wav',
#  'data/raw/02 Creep.wav',
#  'data/raw/06 Venge.wav',
#  'data/raw/02 True .wav',
#  'data/raw/04 Sixte.wav',
#  'data/raw/14 Catch.wav',
#  'data/raw/04 The H.wav',
#  'data/raw/12 Bebot.wav',
#  'data/raw/The Time.wav',
#  'data/raw/05 Tears.wav',
#  "data/raw/10 I'm S.wav",
#  'data/raw/02 Ro(0).wav',
#  'data/raw/03 - Don.wav',
#  'data/raw/07 Missi.wav',
#  'data/raw/05 34C.wav',
#  'data/raw/13 You O.wav',
#  'data/raw/01 Signs.wav',
#  'data/raw/08 Somet.wav',
#  'data/raw/07 Empir.wav',
#  'data/raw/17 Fire.wav',
#  'data/raw/02 Diamo.wav',
#  'data/raw/08 Yello.wav',
#  'data/raw/09 Bonus.wav',
#  'data/raw/01 I Jus.wav',
#  'data/raw/12 You A.wav',
#  'data/raw/07 Celes.wav',
#  'data/raw/13 Blame.wav',
#  'data/raw/02 Learn.wav',
#  'data/raw/03 Guilt.wav',
#  'data/raw/Ram Jam .wav',
#  "data/raw/02 That'.wav",
#  'data/raw/07 You L.wav',
#  'data/raw/08 We Be.wav',
#  'data/raw/07 In Li.wav',
#  'data/raw/02 Act O.wav',
#  "data/raw/14 That'.wav",
#  'data/raw/17 Simpl.wav',
#  'data/raw/11 19-20.wav',
#  'data/raw/05 Go to.wav',
#  'data/raw/15 Battl.wav',
#  'data/raw/11 Caugh.wav',
#  'data/raw/09 Infin.wav',
#  'data/raw/02 Golde.wav',
#  'data/raw/01 Gonna.wav',
#  'data/raw/16 Where.wav',
#  'data/raw/05 Heavy.wav',
#  'data/raw/07 Who W.wav',
#  'data/raw/04 Mk2.wav',
#  'data/raw/02 You K.wav',
#  'data/raw/10 The G.wav',
#  'data/raw/16 Alter.wav',
#  'data/raw/06 R.U. .wav',
#  'data/raw/02 Man I.wav',
#  'data/raw/05 - Mak.wav',
#  'data/raw/14 My Wo.wav',
#  'data/raw/19 Dinah.wav',
#  'data/raw/08 Cause.wav',
#  'data/raw/05 An Ad.wav',
#  "data/raw/03 (Don'.wav",
#  'data/raw/08 Is Th.wav',
#  'data/raw/08 - Ins.wav',
#  'data/raw/09 Track.wav',
#  'data/raw/12 The G.wav',
#  'data/raw/03 Haunt.wav',
#  'data/raw/03 - Hom.wav',
#  'data/raw/11 The L.wav',
#  'data/raw/02 Papil.wav',
#  'data/raw/09 This .wav',
#  'data/raw/14 Going.wav',
#  'data/raw/04 Fat B.wav',
#  'data/raw/20 Overj.wav',
#  'data/raw/07 - Dog.wav',
#  'data/raw/12 Velve.wav',
#  'data/raw/03 The W.wav',
#  'data/raw/06 Shotg.wav',
#  'data/raw/07 Waiti.wav',
#  'data/raw/11 1983..wav',
#  'data/raw/03 Perfe.wav',
#  'data/raw/03 Kille.wav',
#  'data/raw/09 The N.wav',
#  'data/raw/03 Somew.wav',
#  'data/raw/03 Hey L.wav',
#  'data/raw/07 Take .wav',
#  'data/raw/12 Moon,.wav',
#  'data/raw/06 Easie.wav',
#  'data/raw/11 In Co.wav',
#  'data/raw/12 Wake .wav',
#  'data/raw/02 14 Ye.wav',
#  'data/raw/02 A Pas.wav',
#  'data/raw/04 Come .wav',
#  'data/raw/13 Pursu.wav',
#  'data/raw/04 Funky.wav',
#  'data/raw/04 Limel.wav',
#  'data/raw/18 Crack.wav',
#  'data/raw/09 Valen.wav',
#  'data/raw/04 Probl.wav',
#  'data/raw/06 - Ang.wav',
#  'data/raw/06 Are Y.wav',
#  'data/raw/05 Toget.wav',
#  'data/raw/03 Une A.wav',
#  'data/raw/09 Doubl.wav',
#  'data/raw/07 Star.wav',
#  'data/raw/01 The M.wav',
#  'data/raw/01 Finge.wav',
#  'data/raw/12 A Man.wav',
#  'data/raw/07 A Cer.wav',
#  'data/raw/07 Sledg.wav',
#  'data/raw/09 Gone .wav',
#  'data/raw/09 Party.wav',
#  'data/raw/14 Black.wav',
#  'data/raw/04 Illum.wav',
#  'data/raw/06 Faust.wav',
#  'data/raw/17 We Ar.wav',
#  'data/raw/06 Where.wav',
#  'data/raw/06 Magic.wav',
#  'data/raw/15 Somet.wav',
#  'data/raw/02 Vitam.wav',
#  'data/raw/11 One.wav',
#  'data/raw/03 - Zer.wav',
#  'data/raw/03 The D.wav',
#  'data/raw/04 Intim.wav',
#  'data/raw/05 Right.wav',
#  'data/raw/18 Emper.wav',
#  'data/raw/03 Mothe.wav',
#  'data/raw/01 In Di.wav',
#  'data/raw/01 Forew.wav',
#  'data/raw/01 Carry.wav',
#  'data/raw/10 Time .wav',
#  'data/raw/01 - The.wav',
#  'data/raw/02 Purpl.wav',
#  'data/raw/12 Would.wav',
#  'data/raw/12 The T.wav',
#  'data/raw/15 Sir D.wav',
#  'data/raw/05 Exodu.wav',
#  'data/raw/13 Stars.wav',
#  'data/raw/14 Dodo.wav',
#  'data/raw/04 Idiot.wav',
#  'data/raw/08 Prett.wav',
#  'data/raw/21 Part-.wav',
#  'data/raw/09 Prove.wav',
#  'data/raw/02 Hey J.wav',
#  'data/raw/04 Wish .wav',
#  'data/raw/11 Nobod.wav',
#  'data/raw/01 Futur.wav',
#  'data/raw/04 Imma .wav',
#  'data/raw/16 Do Wh.wav',
#  'data/raw/21 My Da.wav',
#  'data/raw/09 Three.wav',
#  'data/raw/07 Squir.wav',
#  'data/raw/10 Ironi.wav',
#  'data/raw/12 Long .wav',
#  'data/raw/11 Castl.wav',
#  'data/raw/11 Rock .wav',
#  'data/raw/14 Manic.wav',
#  'data/raw/06 You A.wav',
#  'data/raw/13 Now G.wav',
#  'data/raw/22. Mary.wav',
#  'data/raw/05 Place.wav',
#  'data/raw/02 Soul .wav',
#  'data/raw/03 I Don.wav',
#  'data/raw/13 Unsen.wav',
#  'data/raw/05 Stylo.wav',
#  'data/raw/18 Do I .wav',
#  'data/raw/05 Angel.wav',
#  'data/raw/10 Rainy.wav',
#  'data/raw/09 Time .wav',
#  'data/raw/09 Whack.wav',
#  'data/raw/11 This .wav',
#  'data/raw/06 Track.wav',
#  'data/raw/06 Among.wav',
#  'data/raw/07 By My.wav',
#  'data/raw/08 Track.wav',
#  'data/raw/08 Burni.wav',
#  'data/raw/Intro Tr.wav',
#  'data/raw/09 A Pla.wav',
#  "data/raw/01 You'r.wav",
#  'data/raw/08 Truth.wav',
#  'data/raw/11 Cudi .wav',
#  'data/raw/05 Bicyc.wav',
#  'data/raw/11 Stuck.wav',
#  'data/raw/10 Shhh!.wav',
#  'data/raw/03 Yeste.wav',
#  'data/raw/05 Drift.wav',
#  'data/raw/08 Haiti.wav',
#  'data/raw/01 Right.wav',
#  'data/raw/11 My Ba.wav',
#  'data/raw/08 The N.wav',
#  'data/raw/11 Be So.wav',
#  'data/raw/08 Gypsy.wav',
#  'data/raw/08 Save .wav',
#  'data/raw/10 Cross.wav',
#  'data/raw/07 Funky.wav',
#  'data/raw/01 Them .wav',
#  'data/raw/14 So Pu.wav',
#  'data/raw/05 Love .wav',
#  'data/raw/03 Moona.wav',
#  'data/raw/12 Lost .wav',
#  'data/raw/06 Quest.wav',
#  'data/raw/19 I Jus.wav',
#  'data/raw/10 Love .wav',
#  'data/raw/01 You.wav',
#  'data/raw/09 Vacan.wav',
#  'data/raw/16 Pirat.wav',
#  'data/raw/11 Sunny.wav',
#  'data/raw/04 - Cli.wav',
#  'data/raw/02 Po Bl.wav',
#  'data/raw/07 Just.wav',
#  'data/raw/06 Witch.wav',
#  'data/raw/02 Catch.wav',
#  "data/raw/03 L'Via.wav",
#  'data/raw/08 No Mo.wav',
#  "data/raw/08 Can't.wav",
#  'data/raw/04 You G.wav',
#  'data/raw/01 Bohem.wav',
#  'data/raw/08 Figur.wav',
#  'data/raw/07 Laces.wav',
#  'data/raw/02 Neigh.wav',
#  'data/raw/06 The K.wav',
#  'data/raw/02 Breas.wav',
#  'data/raw/18 Mare .wav',
#  'data/raw/08 Only.wav',
#  'data/raw/07 Johnn.wav',
#  'data/raw/01 Paper.wav',
#  'data/raw/05 Short.wav',
#  'data/raw/02 With .wav',
#  'data/raw/02 Vcr.wav',
#  'data/raw/13 Still.wav',
#  'data/raw/02 The W.wav',
#  'data/raw/08 Sons .wav',
#  'data/raw/10 Sunsp.wav',
#  'data/raw/07 Store.wav',
#  'data/raw/07 Hands.wav',
#  'data/raw/02 Track.wav',
#  'data/raw/01 - Roc.wav',
#  'data/raw/10 From .wav',
#  'data/raw/03 Chasm.wav',
#  'data/raw/05 Sympa.wav',
#  'data/raw/05 For O.wav',
#  'data/raw/10 Novem.wav',
#  'data/raw/05 While.wav',
#  'data/raw/01 Stead.wav',
#  'data/raw/01 Pump .wav',
#  'data/raw/08 Turn .wav',
#  'data/raw/11 Disco.wav',
#  "data/raw/04 Don't.wav",
#  'data/raw/06 Bury .wav',
#  'data/raw/Fiddles .wav',
#  'data/raw/05 Non B.wav',
#  'data/raw/01 Fathe.wav',
#  'data/raw/06 Sever.wav',
#  'data/raw/07 With .wav',
#  'data/raw/03 - Nig.wav',
#  'data/raw/05 It Ai.wav',
#  'data/raw/05 Ginge.wav',
#  'data/raw/07 Cheye.wav',
#  'data/raw/12 Calgo.wav',
#  'data/raw/12 - Wal.wav',
#  'data/raw/07 Hey Y.wav',
#  'data/raw/10 Track.wav',
#  'data/raw/12 Wasti.wav',
#  'data/raw/08 Joan .wav',
#  'data/raw/15 Growi.wav',
#  'data/raw/06 Kalif.wav',
#  'data/raw/08 Back .wav',
#  'data/raw/03 Have .wav',
#  'data/raw/05 Build.wav',
#  'data/raw/06 Forgi.wav',
#  'data/raw/02 Sysyp.wav',
#  'data/raw/14 Hyyer.wav',
#  'data/raw/14 - Hun.wav',
#  'data/raw/03 Cross.wav',
#  'data/raw/11 The G.wav',
#  'data/raw/02 he Ro.wav',
#  'data/raw/04 Lesso.wav',
#  'data/raw/05 Just .wav',
#  'data/raw/15 Stepp.wav',
#  'data/raw/06 That .wav',
#  'data/raw/05 - Cha.wav',
#  'data/raw/08 Super.wav',
#  'data/raw/08 Littl.wav',
#  'data/raw/10 The P.wav',
#  'data/raw/03 The C.wav',
#  'data/raw/06 Super.wav',
#  'data/raw/09 Seven.wav',
#  'data/raw/06 What .wav',
#  'data/raw/11 The B.wav',
#  'data/raw/16 Littl.wav',
#  'data/raw/10 Video.wav',
#  'data/raw/01 Natur.wav',
#  'data/raw/01 - Reb.wav',
#  'data/raw/10 Brave.wav',
#  'data/raw/18 Hey B.wav',
#  'data/raw/11 Livin.wav',
#  'data/raw/12 Showd.wav',
#  'data/raw/11 Star .wav',
#  'data/raw/02 One S.wav',
#  'data/raw/02 Mad M.wav',
#  "data/raw/02 Don't.wav",
#  'data/raw/04 Ocean.wav',
#  'data/raw/05 Do(0).wav',
#  'data/raw/03 - Hur.wav',
#  'data/raw/15 M1 A1.wav',
#  'data/raw/11 Broke.wav',
#  'data/raw/04 Bleed.wav',
#  'data/raw/09 Ex-Cr.wav',
#  'data/raw/06 A Div.wav',
#  'data/raw/14 Gasol.wav',
#  'data/raw/12 Garde.wav',
#  "data/raw/09 Don't.wav",
#  'data/raw/07 After.wav',
#  'data/raw/03 Sea O.wav',
#  'data/raw/07 Punk.wav',
#  'data/raw/11 Are Y.wav',
#  'data/raw/09 Super.wav',
#  'data/raw/04 E.T.I.wav',
#  'data/raw/01 The N.wav',
#  'data/raw/03 What .wav',
#  'data/raw/04 Mirac.wav',
#  'data/raw/12 Why C.wav',
#  'data/raw/11 Bonus.wav',
#  'data/raw/12 Good .wav',
#  'data/raw/03 Paper.wav',
#  'data/raw/05 I Mig.wav',
#  'data/raw/02 Anoth.wav',
#  'data/raw/08 Elect.wav',
#  'data/raw/13 Boogi.wav',
#  'data/raw/05 Perfe.wav',
#  'data/raw/03 Dirty.wav',
#  'data/raw/06 - I N.wav',
#  'data/raw/10 Purpl.wav',
#  'data/raw/09 Savin.wav',
#  'data/raw/07 So Ap.wav',
#  'data/raw/10 Big B.wav',
#  'data/raw/08 Spit .wav',
#  'data/raw/05 Semi-.wav',
#  'data/raw/05 Would.wav',
#  'data/raw/01 68.wav',
#  'data/raw/08 Favor.wav',
#  'data/raw/08 Dolla.wav',
#  'data/raw/05 All I.wav',
#  'data/raw/01 10000.wav',
#  'data/raw/16 Rabbi.wav',
#  'data/raw/02 The D.wav',
#  'data/raw/10 Debbi.wav',
#  'data/raw/09 Burni.wav',
#  'data/raw/10 Someb.wav',
#  'data/raw/11 Stars.wav',
#  'data/raw/05 Track.wav',
#  'data/raw/24 Anoth.wav',
#  'data/raw/07 Couch.wav',
#  'data/raw/15 Seven.wav',
#  'data/raw/14 To Bi.wav',
#  'data/raw/17 That .wav',
#  'data/raw/02 Its A.wav',
#  'data/raw/03 With .wav',
#  'data/raw/06 Level.wav',
#  'data/raw/03 Sysyp.wav',
#  'data/raw/04 Adren.wav',
#  'data/raw/01 Five .wav',
#  'data/raw/04 Rhine.wav',
#  'data/raw/05 - Too.wav',
#  'data/raw/07 Dirt.wav',
#  'data/raw/02 Again.wav',
#  'data/raw/08 Hope.wav',
#  'data/raw/06 Machi.wav',
#  'data/raw/07 Dance.wav',
#  'data/raw/04 Knock.wav',
#  'data/raw/14 Wind .wav',
#  'data/raw/06 Never.wav',
#  'data/raw/06 Every.wav',
#  'data/raw/06 Acros.wav',
#  'data/raw/08 Glitt.wav',
#  'data/raw/01 Sysyp.wav',
#  'data/raw/20 Pump .wav',
#  'data/raw/04 Weird.wav',
#  'data/raw/05 Diffe.wav',
#  'data/raw/11 Autum.wav',
#  'data/raw/01 Front.wav',
#  'data/raw/07 Untho.wav',
#  'data/raw/10 No Su.wav',
#  'data/raw/05 Opus .wav',
#  'data/raw/08 Fame.wav',
#  'data/raw/16 Angel.wav',
#  'data/raw/05 The C.wav',
#  'data/raw/06 Man R.wav',
#  'data/raw/11 Wanks.wav',
#  'data/raw/18 Wait .wav',
#  'data/raw/09 All A.wav',
#  'data/raw/05 Spind.wav',
#  "data/raw/20 He's .wav",
#  'data/raw/08 Talki.wav',
#  'data/raw/02 Solid.wav',
#  'data/raw/11 Lonel.wav',
#  'data/raw/03 My St.wav',
#  'data/raw/14 Hang .wav',
#  'data/raw/08 - Ass.wav',
#  'data/raw/05 Last .wav',
#  'data/raw/11 Chant.wav',
#  'data/raw/06 Comin.wav',
#  'data/raw/12 Ms. P.wav',
#  'data/raw/03 Meet .wav',
#  'data/raw/13 Candi.wav',
#  'data/raw/02 Dust .wav',
#  'data/raw/06 Babyl.wav',
#  'data/raw/12 Wild .wav',
#  'data/raw/01 Kid O.wav',
#  "data/raw/03 It's .wav",
#  'data/raw/06 Space.wav',
#  'data/raw/11 Elect.wav',
#  'data/raw/09 Break.wav',
#  'data/raw/03 New S.wav',
#  'data/raw/04 Track.wav',
#  'data/raw/08 Ring-.wav',
#  'data/raw/17 Diamo.wav',
#  'data/raw/06 Monst.wav',
#  'data/raw/16 Clint.wav',
#  'data/raw/06 Somet.wav',
#  'data/raw/06 Fanta.wav',
#  'data/raw/13 - Ang.wav',
#  'data/raw/09 Locom.wav',
#  'data/raw/02 Hands.wav',
#  'data/raw/09 Ziggy.wav',
#  'data/raw/02 So Mu.wav',
#  'data/raw/03 Thank.wav',
#  'data/raw/01 Man I.wav',
#  'data/raw/New Song.wav',
#  'data/raw/04 Starm.wav',
#  'data/raw/06 Yet A.wav',
#  'data/raw/03 Dinne.wav',
#  'data/raw/04 Paral.wav',
#  "data/raw/03 What'.wav",
#  'data/raw/06 Its A.wav',
#  'data/raw/11 Now I.wav',
#  'data/raw/14 Audio.wav',
#  'data/raw/02 - Gre.wav',
#  'data/raw/02 Given.wav',
#  'data/raw/03 Float.wav',
#  'data/raw/Ozzy Osb.wav',
#  'data/raw/01 Civil.wav',
#  'data/raw/10 Hell .wav',
#  'data/raw/07 Burni.wav',
#  'data/raw/04 Johnn.wav',
#  'data/raw/11 A Mar.wav',
#  'data/raw/The_Who_.wav',
#  'data/raw/10 What .wav',
#  'data/raw/20 Stay .wav',
#  'data/raw/06 Like .wav',
#  'data/raw/05 This .wav',
#  'data/raw/09 - The.wav',
#  'data/raw/01 This .wav',
#  'data/raw/06 The H.wav',
#  'data/raw/03 Vault.wav',
#  'data/raw/07 That .wav',
#  'data/raw/07 Soul .wav',
#  'data/raw/13 Your .wav',
#  'data/raw/02 Oh! N.wav',
#  'data/raw/16 Coma.wav',
#  'data/raw/09 A New.wav',
#  'data/raw/07 Break.wav',
#  'data/raw/13 In Di.wav',
#  'data/raw/09 Heave.wav',
#  'data/raw/09 Rag &.wav',
#  'data/raw/01 - Wal.wav',
#  'data/raw/09 Mary .wav',
#  'data/raw/01 Fire .wav',
#  'data/raw/03 Broke.wav',
#  'data/raw/09 Swept.wav',
#  'data/raw/15 All A.wav',
#  'data/raw/04 Lying.wav',
#  'data/raw/03 Jumpe.wav',
#  'data/raw/07 A New.wav',
#  'data/raw/04 The W.wav',
#  'data/raw/12 Track.wav',
#  'data/raw/09 Labyr.wav',
#  'data/raw/24 Tina.wav',
#  'data/raw/10 Alive.wav',
#  'data/raw/08 Feel .wav',
#  'data/raw/04 Candi.wav',
#  'data/raw/01 All I.wav',
#  'data/raw/02 Funny.wav',
#  'data/raw/03 How D.wav',
#  'data/raw/03 Cryst.wav',
#  'data/raw/08 Morni.wav',
#  'data/raw/04 Bad B.wav',
#  'data/raw/06 Anger.wav',
#  'data/raw/10 Force.wav',
#  'data/raw/10 Tom W.wav',
#  'data/raw/Strings.wav',
#  'data/raw/10 White.wav',
#  'data/raw/13 Ba Bu.wav',
#  'data/raw/05 Hit T.wav',
#  'data/raw/01 Boom .wav',
#  'data/raw/06 14 Ar.wav',
#  'data/raw/05 I Got.wav',
#  'data/raw/06 Voodo.wav',
#  "data/raw/19 Don't.wav",
#  'data/raw/08 Upsid.wav',
#  'data/raw/11 Acid .wav',
#  'data/raw/04 Right.wav']

# %%
WINDOW_LENGTH = 3  # in seconds
DESIRED_SAMPLE_RATE = 44100
HOP_LENGTH = 2048
N_CLIPS = 20
OUTPUT_DIR = '/home/dante_gates/repos/music-rec/data/train'

# %%
import random
import os

def read_wav(filename):
    """Read wav file and return the sample rate and audio."""
    sr, audio = scipy.io.wavfile.read(filename)
    return _process_audio(sr, audio)

def _process_audio(sr, audio):
    if sr < DESIRED_SAMPLE_RATE:
        raise ValueError('audio has a sample rate less than %s'
                         % DESIRED_SAMPLE_RATE)
    return sr, audio

# TODO: not doing anything with right channel now.
def make_features(sr, audio):
    n_samples = audio.shape[0]
    L, R = audio[:, 0], audio[:, 1]
    window = sr * WINDOW_LENGTH
    samples = random.sample(list(range(n_samples - window)), k=N_CLIPS)
    melspecs = []
    for clip_begin in samples:
        clip = L[clip_begin:clip_begin+window]
        melspec = librosa.feature.melspectrogram(clip, sr, hop_length=HOP_LENGTH)
        melspecs.append(np.reshape(melspec, -1))
    return melspecs

_expected_shape = (8320,)  # for sanity check
def create_training_data(files):
    for file in files:
        try:
            sr, audio = read_wav(file)
        except ValueError as e:
            print(file, e)
        else:
            features = make_features(sr, audio)
            basename = os.path.basename(file)
            for i, feature in enumerate(features, start=1):
                if feature.shape == _expected_shape:
                    saveto = '%s - sample %s.npy' % (basename, i)
                    saveto = os.path.join(OUTPUT_DIR, saveto)
                    np.save(saveto, feature)
                else:
                    print('%s did not have expected shape' % file)

# %%
create_training_data(files)
